# %% [markdown]
# <a href="https://colab.research.google.com/github/Coolio254/3010AI/blob/main/LogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot (1).png](data:image/png;base64,...)

# %% [markdown]
# Logistic Regression
#
# It's a classification rather than algorithm.
#
# It uses an 'S'- shaped curve insead of a straight line makes it a natural fit for driving data into groups.
#
# In this model, the probabilities describing the possible outcomes of a single trial are modeled using a logistic function.
#
#
# Sigmod Function
#
# a(z) =1/(1+e^(-z))
#
# z= h0 (x)=0^Tx
#
# Squash z into (0,1)

# %%
 import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
d=pd.read_csv('/content/3025.csv', header='infer')

# %%
import numpy as np
import matplotlib as mpl

# %%
d
# Out:
#         x       det  Unnamed: 2
# 0   -6.00  0.002473  404.428793
# 1   -5.98  0.002522  396.440368
# 2   -5.96  0.002573  388.610124
# 3   -5.94  0.002625  380.934930
# 4   -5.92  0.002678  373.411714
# ..    ...       ...         ...
# 596  5.92  0.997322    1.002685
# 597  5.94  0.997375    1.002632
# 598  5.96  0.997427    1.002580
# 599  5.98  0.997478    1.002529
# 600  6.00  0.997527    1.002479
#
# [601 rows x 3 columns]

# %%
x=d['x']
y=d['det']

# %%
x
# Out:
# 0     -6.00
# 1     -5.98
# 2     -5.96
# 3     -5.94
# 4     -5.92
#        ...
# 596    5.92
# 597    5.94
# 598    5.96
# 599    5.98
# 600    6.00
# Name: x, Length: 601, dtype: float64

# %%
y
# Out:
# 0      0.002473
# 1      0.002522
# 2      0.002573
# 3      0.002625
# 4      0.002678
#          ...
# 596    0.997322
# 597    0.997375
# 598    0.997427
# 599    0.997478
# 600    0.997527
# Name: det, Length: 601, dtype: float64

# %%
plt.plot(x,y)
plt.show()
